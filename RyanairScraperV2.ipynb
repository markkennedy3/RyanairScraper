# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from selenium import webdriver
import ipywidgets as widgets
from time import sleep
import pandas as pd
import numpy as np
#import smtplib
import time

# %%
airports=[  'Aalborg',
            'Aarhus',
            'Aberdeen',
            'Agadir',
            'Alghero',
            'Alicante',
            'Almeria',
            'Amman Jordan',
            'Amsterdam',
            'Ancona',
            'Antalya',
            'Aqaba Jordan',
            'Athens',
            'Banja Luka',
            'Barcelona',
            'Barcelona Girona',
            'Barcelona Reus',
            'Bari',
            'Basel',
            'Beirut',
            'Belfast International',
            'Bergerac',
            'Berlin Schönefeld',
            'Berlin Tegel',
            'Beziers',
            'Biarritz',
            'Bilbao',
            'Billund',
            'Birmingham',
            'Bodrum',
            'Bologna',
            'Bordeaux',
            'Bournemouth',
            'Bratislava',
            'Bremen',
            'Brest',
            'Brindisi',
            'Bristol',
            'Brive',
            'Brno',
            'Brussels',
            'Brussels Charleroi',
            'Bucharest',
            'Budapest',
            'Burgas',
            'Bydgoszcz',
            'Cagliari',
            'Carcassonne',
            'Cardiff',
            'Casablanca',
            'Castellon (Valencia)',
            'Catania',
            'Chania',
            'Clermont',
            'Cluj',
            'Cologne',
            'Comiso',
            'Copenhage',
            'Corfu',
            'Cork',
            'Crotone',
            'Cuneo',
            'Dalaman',
            'Derry',
            'Dinard',
            'Dole',
            'Dortmund',
            'Dresden',
            'Dublin',
            'Dubrovnik',
            'Dusseldorf Int.',
            'Dusseldorf Weeze',
            'East Midlands',
            'Edinburgh',
            'Eilat Ramon',
            'Eindhoven',
            'Erfurt',
            'Essaouira',
            'Exeter',
            'Faro',
            'Fez',
            'Figari',
            'Frankfurt Hahn',
            'Frankfurt International',
            'Friedrichshafen',
            'Fuerteventura',
            'Gdansk',
            'Geneva',
            'Genoa',
            'Glasgow',
            'Glasgow Prestwick',
            'Gran Canaria',
            'Grenoble',
            'Gyumri – Shirak',
            'Göteborg Landvetter',
            'Hamburg',
            'Hannover',
            'Haugesund',
            'Helsinki',
            'Heraklion Crete',
            'Ibiza',
            'Jerez',
            'Kalamata',
            'Karlsruhe / Baden-Baden',
            'Katowice',
            'Kaunas',
            'Kavala International',
            'Kefalonia',
            'Kerry',
            'Kharkiv International',
            'Kherson',
            'Klagenfurt',
            'Knock',
            'Kos',
            'Kosice',
            'Krakow',
            'Kutaisi',
            'Kyiv',
            'La Rochelle',
            'Lamezia',
            'Lanzarote',
            'Lappeenranta',
            'Larnaca',
            'Leeds Bradford',
            'Lille',
            'Limoges',
            'Lisbon',
            'Liverpool',
            'Lodz',
            'London Gatwick',
            'London Luton',
            'London Southend',
            'London Stansted',
            'Lourdes',
            'Lublin',
            'Luxembourg',
            'Lviv',
            'Lyon',
            'Maastricht',
            'Madrid',
            'Malaga',
            'Malmo',
            'Malta',
            'Manchester',
            'Marrakesh',
            'Marseille',
            'Memmingen',
            'Menorca',
            'Milan Bergamo',
            'Milan Malpensa',
            'Moscow Sheremetyevo',
            'Munich',
            'Murcia International',
            'Mykonos',
            'Münster',
            'Nador',
            'Nantes',
            'Naples',
            'Newcastle',
            'Newquay Cornwall',
            'Nice',
            'Nimes',
            'Nis',
            'Nuremberg',
            'Odesa International',
            'Olsztyn - Mazury',
            'Oradea',
            'Oslo',
            'Oslo Torp',
            'Ostrava',
            'Ouarzazate',
            'Oujda',
            'Ovda',
            'Palanga',
            'Palermo',
            'Palma de Mallorca',
            'Paphos',
            'Pardubice',
            'Paris Beauvais',
            'Paris Vatry',
            'Parma',
            'Perpignan',
            'Perugia',
            'Pescara',
            'Pisa',
            'Plovdiv',
            'Podgorica',
            'Poitiers',
            'Ponta Delgada',
            'Porto',
            'Poznan',
            'Prague',
            'Preveza - Aktion',
            'Pula',
            'Rabat',
            'Rhodes',
            'Riga',
            'Rijeka',
            'Rimini',
            'Rodez',
            'Rome Ciampino',
            'Rome Fiumicino',
            'Rostock',
            'Rzeszow',
            'Salzburg',
            'Santander',
            'Santiago',
            'Santorini',
            'Seville',
            'Shannon',
            'Skiathos',
            'Sofia',
            'SplitV',
            'St. Petersburg',
            'Stockholm Skavsta',
            'Stockholm Västerås',
            'Strasbourg',
            'Stuttgart',
            'Szczecin',
            'Tallinn',
            'Tampere',
            'Tangier',
            'Tbilisi',
            'Tel Aviv',
            'Tenerife North',
            'Tenerife South',
            'Terceira Lajes',
            'Thessaloniki',
            'Timisoara',
            'Toulouse',
            'Tours Loire Valley',
            'Trapani',
            'Trieste',
            'Tunis',
            'Turin',
            'Tétouan',
            'Valencia',
            'Valladolid',
            'Varna',
            'Venice M.Polo',
            'Venice Treviso',
            'Verona',
            'Vienna',
            'Vilnius',
            'Vitoria (Basque Country)',
            'Växjö Småland',
            'Warsaw Modlin',
            'Wroclaw',
            'Yerevan - Zvartnots',
            'Zadar',
            'Zakynthos',
            'Zaragoza',
            'Zurich']

# %%
airport_abbreviations = [   'AAL',
                            'AAR',
                            'ABZ',
                            'AGA',
                            'AHO',
                            'ALC',
                            'LEI',
                            'AMM',
                            'AMS',
                            'AOI',
                            'AYT',
                            'AQJ',
                            'ATH',
                            'BNX',
                            'BCN',
                            'GRO',
                            'REU',
                            'BRI',
                            'BSL',
                            'BEY',
                            'BFS',
                            'EGC',
                            'SXF',
                            'TXL',
                            'BZR',
                            'BIQ',
                            'BIO',
                            'BLL',
                            'BHX',
                            'BJV',
                            'BLQ',
                            'BOD',
                            'BOH',
                            'BTS',
                            'BRE',
                            'BES',
                            'BDS',
                            'BRS',
                            'BVE',
                            'BRQ',
                            'BRU',
                            'CRL',
                            'OTP',
                            'BUD',
                            'BOJ',
                            'BZG',
                            'CAG',
                            'CCF',
                            'CWL',
                            'CMN',
                            'CDT',
                            'CTA',
                            'CHQ',
                            'CFE',
                            'CLJ',
                            'CGN',
                            'CIY',
                            'CPH',
                            'CFU',
                            'ORK',
                            'CRV',
                            'CUF',
                            'DLM',
                            'LDY',
                            'DNR',
                            'DLE',
                            'DTM',
                            'DRS',
                            'DUB',
                            'DBV',
                            'DUS',
                            'NRN',
                            'EMA',
                            'EDI',
                            'ETM',
                            'EIN',
                            'ERF',
                            'ESU',
                            'EXT',
                            'FAO',
                            'FEZ',
                            'FSC',
                            'HHN',
                            'FRA',
                            'FDH',
                            'FUE',
                            'GDN',
                            'GVA',
                            'GOA',
                            'GLA',
                            'PIK',
                            'LPA',
                            'GNB',
                            'LWN',
                            'GOT',
                            'HAM',
                            'HAJ',
                            'HAU',
                            'HEL',
                            'HER',
                            'IBZ',
                            'XRY',
                            'KLX',
                            'FKB',
                            'KTW',
                            'KUN',
                            'KVA',
                            'EFL',
                            'KIR',
                            'HRK',
                            'KHE',
                            'KLU',
                            'NOC',
                            'KGS',
                            'KSC',
                            'KRK',
                            'KUT',
                            'KBP',
                            'LRH',
                            'SUF',
                            'ACE',
                            'LPP',
                            'LCA',
                            'LBA',
                            'LIL',
                            'LIG',
                            'LIS',
                            'LPL',
                            'LCJ',
                            'LGW',
                            'LTN',
                            'SEN',
                            'STN',
                            'LDE',
                            'LUZ',
                            'LUX',
                            'LWO',
                            'LYS',
                            'MST',
                            'MAD',
                            'AGP',
                            'MMX',
                            'MLA',
                            'MAN',
                            'RAK',
                            'MRS',
                            'FMM',
                            'MAH',
                            'BGY',
                            'MXP',
                            'SVO',
                            'MUC',
                            'RMU',
                            'JMK',
                            'FMO',
                            'NDR',
                            'NTE',
                            'NAP',
                            'NCL',
                            'NQY',
                            'NCE',
                            'FNI',
                            'INI',
                            'NUE',
                            'ODS',
                            'SZY',
                            'OMR',
                            'OSL',
                            'TRF',
                            'OSR',
                            'OZZ',
                            'OUD',
                            'VDA',
                            'PLQ',
                            'PMO',
                            'PMI',
                            'PFO',
                            'PED',
                            'BVA',
                            'XCR',
                            'PMF',
                            'PGF',
                            'PEG',
                            'PSR',
                            'PSA',
                            'PDV',
                            'TGD',
                            'PIS',
                            'PDL',
                            'OPO',
                            'POZ',
                            'PRG',
                            'PVK',
                            'PUY',
                            'RBA',
                            'RHO',
                            'RIX',
                            'RJK',
                            'RMI',
                            'RDZ',
                            'CIA',
                            'FCO',
                            'RLG',
                            'RZE',
                            'SZG',
                            'SDR',
                            'SCQ',
                            'JTR',
                            'SVQ',
                            'SNN',
                            'JSI',
                            'SOF',
                            'SPU',
                            'LED',
                            'NYO',
                            'VST',
                            'SXB',
                            'STR',
                            'SZZ',
                            'TLL',
                            'TMP',
                            'TNG',
                            'TBS',
                            'TLV',
                            'TFN',
                            'TFS',
                            'TER',
                            'SKG',
                            'TSR',
                            'TLS',
                            'TUF',
                            'TPS',
                            'TRS',
                            'TUN',
                            'TRN',
                            'TTU',
                            'VLC',
                            'VLL',
                            'VAR',
                            'VCE',
                            'TSF',
                            'VRN',
                            'VIE',
                            'VNO',
                            'VIT',
                            'VXO',
                            'WMI',
                            'WRO',
                            'EVN',
                            'ZAD',
                            'ZTH',
                            'ZAZ',
                            'ZRH'
                            ]

# %%
user_input =widgets.Dropdown(
    options=airports,
    value='Dublin',
    description='From:',
    disabled=False,
)
user_input
# Out:
# Dropdown(description='From:', index=68, options=('Aalborg', 'Aarhus', 'Aberdeen', 'Agadir', 'Alghero', 'Alican…

# %%
city_from = user_input.value

# %%
airport_dict = dict(zip(airport_abbreviations, airports))

# %%
# function to return key for any value 
def get_key(val): 
    for key, value in airport_dict.items(): 
         if val == value: 
            return key 
  
    return "key doesn't exist"

# %% [markdown]
# out_date = widgets.DatePicker(
#     description='Out Date',
#     disabled=False
# )
# out_date

# %%
out_date = '2020-11-14'

# %% [markdown]
# return_date = widgets.DatePicker(
#     description='Return Date',
#     disabled=False
# )
# return_date

# %%
return_date = '2020-11-15'

# %%
budget = widgets.IntSlider(
                    value=7,
                    min=50,
                    max=1000,
                    step=50,
                    description='Budget:',
                    disabled=False,
                    continuous_update=False,
                    orientation='horizontal',
                    readout=True,
                    readout_format='d'
                )
budget
# Out:
# IntSlider(value=50, continuous_update=False, description='Budget:', max=1000, min=50, step=50)

# %%
sec = input('PRESS THE NUMBER 1, AND THEN ENTER WHEN YOUR INPUTS HAVE BEEN RECORDED.\n')

time.sleep(int(sec))
# Out:
# PRESS THE NUMBER 1, AND THEN ENTER WHEN YOUR INPUTS HAVE BEEN RECORDED.
# 1

# %%
chromedriver_path = '/Users/markkennedy/Documents/WebDriver/chromedriver'
driver = webdriver.Chrome(executable_path=chromedriver_path)
sleep(5)

# %%
ryanair = ('https://www.ryanair.com/ie/en/cheap-flights/?from=' + get_key(city_from) + '&out-from-date=' + out_date  + '&out-to-date=' + out_date + '&in-from-date=' + return_date + '&in-to-date=' + return_date + '&budget=' + str(budget.value))
driver.get(ryanair)
sleep(10)

# %%
sections_list = []

# %%
def page_scrape():
    xp_sections = '//*[@class="ff-list-item"]'
    sections = driver.find_elements_by_xpath(xp_sections)
    temp_sections_list = ([value.text for value in sections])
    temp_sections_list = [x.replace('in ', "") for x in temp_sections_list]
    temp_sections_list = ([value.split("\n") for value in temp_sections_list])
    sections_list.append(temp_sections_list)

# %%
def load_next_page():
    next_page = '//div[contains(@class,"next vertical-center")]'
    driver.find_elements_by_xpath(next_page)[0].click()
    sleep(3)

# %%
def check_next_page():
    next_prev_buttons = '//span [contains(@class,"nav-label")]'
    next_prev_buttons = driver.find_elements_by_xpath(next_prev_buttons)
    button_labels = [value.text for value in next_prev_buttons]
    next_button_label = 'Next'
    if next_button_label in button_labels:
        return True
    else:
        return False

# %%
sleep(20)

while True:
        page_scrape()
        if check_next_page() == False:
            break
        else:
            load_next_page()

# %%
sections_array = np.concatenate(sections_list, axis=0 )

# %%
columns = ["City", "Country", "Month", "Price", "Ticket"]
df = pd.DataFrame(data=sections_array, columns=columns)

# %%
df
# Out:
#                        City         Country     Month     Price       Ticket
# 0           London Southend  United Kingdom  November   € 62.19  Return trip
# 1              London Luton  United Kingdom  November   € 63.84  Return trip
# 2           London Stansted  United Kingdom  November   € 63.84  Return trip
# 3            Leeds Bradford  United Kingdom  November   € 66.49  Return trip
# 4             East Midlands  United Kingdom  November   € 68.19  Return trip
# 5               Bournemouth  United Kingdom  November   € 70.88  Return trip
# 6                Birmingham  United Kingdom  November   € 72.36  Return trip
# 7                 Edinburgh  United Kingdom  November   € 72.36  Return trip
# 8                 Liverpool  United Kingdom  November   € 72.36  Return trip
# 9                Manchester  United Kingdom  November   € 72.36  Return trip
# 10                Newcastle  United Kingdom  November   € 72.36  Return trip
# 11           London Gatwick  United Kingdom  November   € 72.88  Return trip
# 12                 Brussels         Belgium  November   € 74.98  Return trip
# 13                  Glasgow  United Kingdom  November   € 76.41  Return trip
# 14           Paris Beauvais          France  November   € 78.98  Return trip
# 15                   Madrid           Spain  November   € 81.98  Return trip
# 16            Milan Bergamo           Italy  November   € 81.98  Return trip
# 17                  Cologne         Germany  November   € 83.98  Return trip
# 18                Amsterdam     Netherlands  November   € 84.98  Return trip
# 19                   Lisbon        Portugal  November   € 84.98  Return trip
# 20                Barcelona           Spain  November   € 85.98  Return trip
# 21  Frankfurt International         Germany  November   € 85.98  Return trip
# 22                  Bristol  United Kingdom  November   € 89.97  Return trip
# 23                Eindhoven     Netherlands  November   € 90.98  Return trip
# 24           Milan Malpensa           Italy  November   € 90.98  Return trip
# 25                  Hamburg         Germany  November  € 104.98  Return trip
# 26                   Prague  Czech Republic  November  € 114.52  Return trip
# 27           BerlSchönefeld         Germany  November  € 121.98  Return trip
# 28                   Malaga           Spain  November  € 122.98  Return trip
# 29                   Krakow          Poland  November  € 129.43  Return trip
# 30                     Faro        Portugal  November  € 131.98  Return trip
# 31            Rome Ciampino           Italy  November  € 131.98  Return trip
# 32                 Budapest         Hungary  November  € 132.20  Return trip
# 33                     Riga          Latvia  November  € 143.98  Return trip
# 34               Bratislava        Slovakia  November  € 145.98  Return trip
# 35               Copenhagen         Denmark  November  € 148.93  Return trip

# %%
driver.close()
