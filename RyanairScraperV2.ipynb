# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.multipart import MIMEMultipart
import numpy as np
import ipywidgets as widgets
import time

# %%
airports=[  'Aalborg',
            'Aarhus',
            'Aberdeen',
            'Agadir',
            'Alghero',
            'Alicante',
            'Almeria',
            'Amman Jordan',
            'Amsterdam',
            'Ancona',
            'Antalya',
            'Aqaba Jordan',
            'Athens',
            'Banja Luka',
            'Barcelona',
            'Barcelona Girona',
            'Barcelona Reus',
            'Bari',
            'Basel',
            'Beirut',
            'Belfast International',
            'Bergerac',
            'Berlin Schönefeld',
            'Berlin Tegel',
            'Beziers',
            'Biarritz',
            'Bilbao',
            'Billund',
            'Birmingham',
            'Bodrum',
            'Bologna',
            'Bordeaux',
            'Bournemouth',
            'Bratislava',
            'Bremen',
            'Brest',
            'Brindisi',
            'Bristol',
            'Brive',
            'Brno',
            'Brussels',
            'Brussels Charleroi',
            'Bucharest',
            'Budapest',
            'Burgas',
            'Bydgoszcz',
            'Cagliari',
            'Carcassonne',
            'Cardiff',
            'Casablanca',
            'Castellon (Valencia)',
            'Catania',
            'Chania',
            'Clermont',
            'Cluj',
            'Cologne',
            'Comiso',
            'Copenhage',
            'Corfu',
            'Cork',
            'Crotone',
            'Cuneo',
            'Dalaman',
            'Derry',
            'Dinard',
            'Dole',
            'Dortmund',
            'Dresden',
            'Dublin',
            'Dubrovnik',
            'Dusseldorf Int.',
            'Dusseldorf Weeze',
            'East Midlands',
            'Edinburgh',
            'Eilat Ramon',
            'Eindhoven',
            'Erfurt',
            'Essaouira',
            'Exeter',
            'Faro',
            'Fez',
            'Figari',
            'Frankfurt Hahn',
            'Frankfurt International',
            'Friedrichshafen',
            'Fuerteventura',
            'Gdansk',
            'Geneva',
            'Genoa',
            'Glasgow',
            'Glasgow Prestwick',
            'Gran Canaria',
            'Grenoble',
            'Gyumri – Shirak',
            'Göteborg Landvetter',
            'Hamburg',
            'Hannover',
            'Haugesund',
            'Helsinki',
            'Heraklion Crete',
            'Ibiza',
            'Jerez',
            'Kalamata',
            'Karlsruhe / Baden-Baden',
            'Katowice',
            'Kaunas',
            'Kavala International',
            'Kefalonia',
            'Kerry',
            'Kharkiv International',
            'Kherson',
            'Klagenfurt',
            'Knock',
            'Kos',
            'Kosice',
            'Krakow',
            'Kutaisi',
            'Kyiv',
            'La Rochelle',
            'Lamezia',
            'Lanzarote',
            'Lappeenranta',
            'Larnaca',
            'Leeds Bradford',
            'Lille',
            'Limoges',
            'Lisbon',
            'Liverpool',
            'Lodz',
            'London Gatwick',
            'London Luton',
            'London Southend',
            'London Stansted',
            'Lourdes',
            'Lublin',
            'Luxembourg',
            'Lviv',
            'Lyon',
            'Maastricht',
            'Madrid',
            'Malaga',
            'Malmo',
            'Malta',
            'Manchester',
            'Marrakesh',
            'Marseille',
            'Memmingen',
            'Menorca',
            'Milan Bergamo',
            'Milan Malpensa',
            'Moscow Sheremetyevo',
            'Munich',
            'Murcia International',
            'Mykonos',
            'Münster',
            'Nador',
            'Nantes',
            'Naples',
            'Newcastle',
            'Newquay Cornwall',
            'Nice',
            'Nimes',
            'Nis',
            'Nuremberg',
            'Odesa International',
            'Olsztyn - Mazury',
            'Oradea',
            'Oslo',
            'Oslo Torp',
            'Ostrava',
            'Ouarzazate',
            'Oujda',
            'Ovda',
            'Palanga',
            'Palermo',
            'Palma de Mallorca',
            'Paphos',
            'Pardubice',
            'Paris Beauvais',
            'Paris Vatry',
            'Parma',
            'Perpignan',
            'Perugia',
            'Pescara',
            'Pisa',
            'Plovdiv',
            'Podgorica',
            'Poitiers',
            'Ponta Delgada',
            'Porto',
            'Poznan',
            'Prague',
            'Preveza - Aktion',
            'Pula',
            'Rabat',
            'Rhodes',
            'Riga',
            'Rijeka',
            'Rimini',
            'Rodez',
            'Rome Ciampino',
            'Rome Fiumicino',
            'Rostock',
            'Rzeszow',
            'Salzburg',
            'Santander',
            'Santiago',
            'Santorini',
            'Seville',
            'Shannon',
            'Skiathos',
            'Sofia',
            'SplitV',
            'St. Petersburg',
            'Stockholm Skavsta',
            'Stockholm Västerås',
            'Strasbourg',
            'Stuttgart',
            'Szczecin',
            'Tallinn',
            'Tampere',
            'Tangier',
            'Tbilisi',
            'Tel Aviv',
            'Tenerife North',
            'Tenerife South',
            'Terceira Lajes',
            'Thessaloniki',
            'Timisoara',
            'Toulouse',
            'Tours Loire Valley',
            'Trapani',
            'Trieste',
            'Tunis',
            'Turin',
            'Tétouan',
            'Valencia',
            'Valladolid',
            'Varna',
            'Venice M.Polo',
            'Venice Treviso',
            'Verona',
            'Vienna',
            'Vilnius',
            'Vitoria (Basque Country)',
            'Växjö Småland',
            'Warsaw Modlin',
            'Wroclaw',
            'Yerevan - Zvartnots',
            'Zadar',
            'Zakynthos',
            'Zaragoza',
            'Zurich']

# %%
airport_abbreviations = [   'AAL',
                            'AAR',
                            'ABZ',
                            'AGA',
                            'AHO',
                            'ALC',
                            'LEI',
                            'AMM',
                            'AMS',
                            'AOI',
                            'AYT',
                            'AQJ',
                            'ATH',
                            'BNX',
                            'BCN',
                            'GRO',
                            'REU',
                            'BRI',
                            'BSL',
                            'BEY',
                            'BFS',
                            'EGC',
                            'SXF',
                            'TXL',
                            'BZR',
                            'BIQ',
                            'BIO',
                            'BLL',
                            'BHX',
                            'BJV',
                            'BLQ',
                            'BOD',
                            'BOH',
                            'BTS',
                            'BRE',
                            'BES',
                            'BDS',
                            'BRS',
                            'BVE',
                            'BRQ',
                            'BRU',
                            'CRL',
                            'OTP',
                            'BUD',
                            'BOJ',
                            'BZG',
                            'CAG',
                            'CCF',
                            'CWL',
                            'CMN',
                            'CDT',
                            'CTA',
                            'CHQ',
                            'CFE',
                            'CLJ',
                            'CGN',
                            'CIY',
                            'CPH',
                            'CFU',
                            'ORK',
                            'CRV',
                            'CUF',
                            'DLM',
                            'LDY',
                            'DNR',
                            'DLE',
                            'DTM',
                            'DRS',
                            'DUB',
                            'DBV',
                            'DUS',
                            'NRN',
                            'EMA',
                            'EDI',
                            'ETM',
                            'EIN',
                            'ERF',
                            'ESU',
                            'EXT',
                            'FAO',
                            'FEZ',
                            'FSC',
                            'HHN',
                            'FRA',
                            'FDH',
                            'FUE',
                            'GDN',
                            'GVA',
                            'GOA',
                            'GLA',
                            'PIK',
                            'LPA',
                            'GNB',
                            'LWN',
                            'GOT',
                            'HAM',
                            'HAJ',
                            'HAU',
                            'HEL',
                            'HER',
                            'IBZ',
                            'XRY',
                            'KLX',
                            'FKB',
                            'KTW',
                            'KUN',
                            'KVA',
                            'EFL',
                            'KIR',
                            'HRK',
                            'KHE',
                            'KLU',
                            'NOC',
                            'KGS',
                            'KSC',
                            'KRK',
                            'KUT',
                            'KBP',
                            'LRH',
                            'SUF',
                            'ACE',
                            'LPP',
                            'LCA',
                            'LBA',
                            'LIL',
                            'LIG',
                            'LIS',
                            'LPL',
                            'LCJ',
                            'LGW',
                            'LTN',
                            'SEN',
                            'STN',
                            'LDE',
                            'LUZ',
                            'LUX',
                            'LWO',
                            'LYS',
                            'MST',
                            'MAD',
                            'AGP',
                            'MMX',
                            'MLA',
                            'MAN',
                            'RAK',
                            'MRS',
                            'FMM',
                            'MAH',
                            'BGY',
                            'MXP',
                            'SVO',
                            'MUC',
                            'RMU',
                            'JMK',
                            'FMO',
                            'NDR',
                            'NTE',
                            'NAP',
                            'NCL',
                            'NQY',
                            'NCE',
                            'FNI',
                            'INI',
                            'NUE',
                            'ODS',
                            'SZY',
                            'OMR',
                            'OSL',
                            'TRF',
                            'OSR',
                            'OZZ',
                            'OUD',
                            'VDA',
                            'PLQ',
                            'PMO',
                            'PMI',
                            'PFO',
                            'PED',
                            'BVA',
                            'XCR',
                            'PMF',
                            'PGF',
                            'PEG',
                            'PSR',
                            'PSA',
                            'PDV',
                            'TGD',
                            'PIS',
                            'PDL',
                            'OPO',
                            'POZ',
                            'PRG',
                            'PVK',
                            'PUY',
                            'RBA',
                            'RHO',
                            'RIX',
                            'RJK',
                            'RMI',
                            'RDZ',
                            'CIA',
                            'FCO',
                            'RLG',
                            'RZE',
                            'SZG',
                            'SDR',
                            'SCQ',
                            'JTR',
                            'SVQ',
                            'SNN',
                            'JSI',
                            'SOF',
                            'SPU',
                            'LED',
                            'NYO',
                            'VST',
                            'SXB',
                            'STR',
                            'SZZ',
                            'TLL',
                            'TMP',
                            'TNG',
                            'TBS',
                            'TLV',
                            'TFN',
                            'TFS',
                            'TER',
                            'SKG',
                            'TSR',
                            'TLS',
                            'TUF',
                            'TPS',
                            'TRS',
                            'TUN',
                            'TRN',
                            'TTU',
                            'VLC',
                            'VLL',
                            'VAR',
                            'VCE',
                            'TSF',
                            'VRN',
                            'VIE',
                            'VNO',
                            'VIT',
                            'VXO',
                            'WMI',
                            'WRO',
                            'EVN',
                            'ZAD',
                            'ZTH',
                            'ZAZ',
                            'ZRH'
                            ]

# %%
user_input =widgets.Dropdown(
    options=airports,
    value='Dublin',
    description='From:',
    disabled=False,
)
user_input
# Out:
# Dropdown(description='From:', index=68, options=('Aalborg', 'Aarhus', 'Aberdeen', 'Agadir', 'Alghero', 'Alican…

# %%
city_from = user_input.value

# %%
airport_dict = dict(zip(airport_abbreviations, airports))

# %%
# function to return key for any value 
def get_key(val): 
    for key, value in airport_dict.items(): 
         if val == value: 
            return key 
  
    return "key doesn't exist"

# %%
out_date = widgets.DatePicker(
    description='Out Date',
    disabled=False
)
out_date
# Out:
# DatePicker(value=None, description='Out Date')

# %%
return_date = widgets.DatePicker(
    description='Return Date',
    disabled=False
)
return_date
# Out:
# DatePicker(value=None, description='Return Date')

# %%
budget = widgets.IntSlider(
                    value=7,
                    min=50,
                    max=1000,
                    step=50,
                    description='Budget:',
                    disabled=False,
                    continuous_update=False,
                    orientation='horizontal',
                    readout=True,
                    readout_format='d'
                )
budget
# Out:
# IntSlider(value=50, continuous_update=False, description='Budget:', max=1000, min=50, step=50)

# %%
sec = input('PRESS THE NUMBER 1, AND THEN ENTER WHEN YOUR INPUTS HAVE BEEN RECORDED.\n')

time.sleep(int(sec))
# Out:
# PRESS 1 WHEN YOUR INPUTS HAVE BEEN RECORDED.
# 1

# %%
chromedriver_path = '/Users/markkennedy/Documents/WebDriver/chromedriver'
driver = webdriver.Chrome(executable_path=chromedriver_path)
sleep(5)

# %%
ryanair = ('https://www.ryanair.com/ie/en/cheap-flights/?from=' + get_key(city_from) + '&out-from-date=' + str(out_date.value) + '&out-to-date=' + str(out_date.value) + '&in-from-date=' + str(return_date.value) + '&in-to-date=2020-07-01&budget=' + str(budget.value))
driver.get(ryanair)
sleep(10)

# %%
sections_list = []

def page_scrape():
    xp_sections = '//*[@class="ff-list-item"]'
    sections = driver.find_elements_by_xpath(xp_sections)
    temp_sections_list = ([value.text for value in sections])
    temp_sections_list = [x.replace('in ', "") for x in temp_sections_list]
    temp_sections_list = ([value.split("\n") for value in temp_sections_list])
    sections_list.append(temp_sections_list)

# %%
def load_next_page():
    next_page = '//div[contains(@class,"next vertical-center")]'
    driver.find_elements_by_xpath(next_page)[0].click()
    sleep(3)

# %%
def check_next_page():
    next_prev_buttons = '//span [contains(@class,"nav-label")]'
    next_prev_buttons = driver.find_elements_by_xpath(next_prev_buttons)
    button_labels = [value.text for value in next_prev_buttons]
    next_button_label = 'Next'
    if next_button_label in button_labels:
        return True
    else:
        return False

# %%
sleep(5)

while True:
        page_scrape()
        if check_next_page() == False:
            break
        else:
            load_next_page()

# %%
sections_array = np.concatenate(sections_list, axis=0 )

# %%
columns = ["City", "Country", "Month", "Price", "Ticket"]
df = pd.DataFrame(data=sections_array, columns=columns)

# %%
df
# Out:
#                         City         Country  Month     Price   Ticket
# 0                 Birmingham  United Kingdom    May   € 20.99  One way
# 1             London Gatwick  United Kingdom    May   € 20.99  One way
# 2               London Luton  United Kingdom    May   € 20.99  One way
# 3            London Southend  United Kingdom    May   € 20.99  One way
# 4            London Stansted  United Kingdom    May   € 20.99  One way
# 5                 Manchester  United Kingdom    May   € 20.99  One way
# 6                     Madrid           Spain    May   € 38.99  One way
# 7                   Alicante           Spain    May   € 39.99  One way
# 8                    Almeria           Spain    May   € 39.99  One way
# 9                  Amsterdam     Netherlands  April   € 39.99  One way
# 10                 Barcelona           Spain    May   € 39.99  One way
# 11                      Bari           Italy    May   € 39.99  One way
# 12                     Basel     Switzerland    May   € 39.99  One way
# 13            BerlSchönefeld         Germany  April   € 39.99  One way
# 14                   Billund         Denmark    May   € 39.99  One way
# 15                   Bologna           Italy    May   € 39.99  One way
# 16                  Bordeaux          France    May   € 39.99  One way
# 17               Bournemouth  United Kingdom    May   € 39.99  One way
# 18                Bratislava        Slovakia    May   € 39.99  One way
# 19                   Bristol  United Kingdom  April   € 39.99  One way
# 20                  Brussels         Belgium  April   € 39.99  One way
# 21        Brussels Charleroi         Belgium    May   € 39.99  One way
# 22                 Bydgoszcz          Poland    May   € 39.99  One way
# 23                   Cologne         Germany    May   € 39.99  One way
# 24                Copenhagen         Denmark    May   € 39.99  One way
# 25             East Midlands  United Kingdom    May   € 39.99  One way
# 26                 Edinburgh  United Kingdom  April   € 39.99  One way
# 27                 Eindhoven     Netherlands    May   € 39.99  One way
# 28                      Faro        Portugal    May   € 39.99  One way
# 29   Frankfurt International         Germany    May   € 39.99  One way
# ..                       ...             ...    ...       ...      ...
# 77                 Lanzarote           Spain    May   € 54.99  One way
# 78            Tenerife South           Spain    May   € 54.99  One way
# 79                      Lodz          Poland    May   € 55.99  One way
# 80                   Menorca           Spain   June   € 55.99  One way
# 81                   Rzeszow          Poland    May   € 55.99  One way
# 82                     Sofia        Bulgaria    May   € 55.99  One way
# 83              Thessaloniki          Greece    May   € 55.99  One way
# 84                   Wroclaw          Poland    May   € 55.99  One way
# 85                  Katowice          Poland    May   € 58.99  One way
# 86                      Kyiv         Ukraine    May   € 58.99  One way
# 87                  Valencia           Spain   June   € 59.99  One way
# 88                    Lublin          Poland    May   € 61.99  One way
# 89                    Krakow          Poland    May   € 64.99  One way
# 90                   Seville           Spain    May   € 74.99  One way
# 91             Fuerteventura           Spain    May   € 75.99  One way
# 92                 Marrakesh         Morocco    May   € 75.99  One way
# 93                    Paphos          Cyprus    May   € 75.99  One way
# 94                     Split         Croatia   June   € 77.99  One way
# 95                   Vilnius       Lithuania    May   € 80.99  One way
# 96                     Ibiza           Spain    May   € 81.99  One way
# 97                    Kaunas       Lithuania    May   € 81.99  One way
# 98                 Dubrovnik         Croatia   July   € 83.99  One way
# 99                    Athens          Greece    May   € 86.99  One way
# 100                   Chania          Greece    May   € 86.99  One way
# 101                 Brindisi           Italy    May   € 91.33  One way
# 102                  Lamezia           Italy    May   € 92.33  One way
# 103                 Cagliari           Italy   June   € 92.99  One way
# 104                   Bodrum          Turkey    May   € 99.99  One way
# 105         Barcelona Girona           Spain   June  € 100.99  One way
# 106                  Dalaman          Turkey   June  € 118.99  One way
#
# [107 rows x 5 columns]

# %%
driver.close()
